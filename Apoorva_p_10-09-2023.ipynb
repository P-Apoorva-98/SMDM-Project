# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("austo_automobile.csv")

# %%
print("no. of rows: ",df.shape[0], "\n""no. of columns: ",df.shape[1])
# Out:
# no. of rows:  1581
# no. of columns:  14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
df['Profession'].unique()
# Out:
# array(['Business', 'Salaried'], dtype=object)

# %%
df['Marital_status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
df['Education'].unique()
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
df['Personal_loan'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['House_loan'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Partner_working'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Make'].unique()
# Out:
# array(['SUV', 'Sedan', 'Hatchback'], dtype=object)

# %%
df['Gender'].replace('Femal','Female',inplace=True)

# %%
df['Gender'].replace('Femle','Female',inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
#df.Gender.fillna('Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64

# %%
df.Partner_salary.fillna(0.0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     31.922201      8.425978     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  60392.220114  14674.825044  30000.0  51900.0
# Partner_salary    1581.0  18869.512966  19570.644035      0.0      0.0
# Total_salary      1581.0  79625.996205  25545.857768  30000.0  60500.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      54.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59500.0  71800.0   99300.0
# Partner_salary    24900.0  38000.0   80500.0
# Total_salary      78000.0  95900.0  171000.0
# Price             31000.0  47000.0   70000.0

# %%
#univariate analysis

# %%
fig, axes = plt.subplots(nrows=5,ncols=2)
fig.set_size_inches(20,20)
sns.histplot(df['Salary'], kde=True, ax=axes[0][0])
sns.boxplot(x='Salary', data=df, ax=axes[0][1])
sns.histplot(df['Partner_salary'] , kde=True, ax=axes[1][0])
sns.boxplot(x='Partner_salary', data=df , ax=axes[1][1])
sns.histplot(df['Total_salary'], kde=True, ax=axes[2][0])
sns.boxplot(x='Total_salary', data=df, ax=axes[2][1])
sns.histplot(df['Price'], kde=True, ax=axes[3][0])
sns.boxplot(x='Price', data=df, ax=axes[3][1])
sns.histplot(df['Age'], kde=True, ax=axes[4][0])
sns.boxplot(x='Age', data=df, ax=axes[4][1])
plt.show()

# %%
#categorical value

# %%
fig, axes = plt.subplots(nrows=3,ncols=3)
fig.set_size_inches(12,12)
sns.countplot(x='Gender', data=df, palette='pastel',ax=axes[0][0])
sns.countplot(x='Education', data=df, palette='pastel',ax=axes[0][1])
sns.countplot(x='Profession', data=df, palette='pastel',ax=axes[0][2])
sns.countplot(x='Marital_status', data=df, palette='pastel',ax=axes[1][0])
sns.countplot(x='No_of_Dependents', data=df, palette='pastel',ax=axes[1][1])
sns.countplot(x='Personal_loan', data=df, palette='pastel',ax=axes[1][2])
sns.countplot(x='House_loan', data=df, palette='pastel',ax=axes[2][0])
sns.countplot(x='Partner_working', data=df, palette='pastel',ax=axes[2][1])
sns.countplot(x='Make', data=df, palette='pastel',ax=axes[2][2])
plt.show()

# %%
print(df['Gender'].value_counts())
print("\n")
print(df['Education'].value_counts())
print("\n")
print(df['Profession'].value_counts())
print("\n")
print(df['Marital_status'].value_counts())
print("\n")
print(df['No_of_Dependents'].value_counts())
print("\n")
print(df['Personal_loan'].value_counts())
print("\n")
print(df['House_loan'].value_counts())
print("\n")
print(df['Partner_working'].value_counts())
print("\n")
print(df['Make'].value_counts())
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64
#
#
# Post Graduate    985
# Graduate         596
# Name: Education, dtype: int64
#
#
# Salaried    896
# Business    685
# Name: Profession, dtype: int64
#
#
# Married    1443
# Single      138
# Name: Marital_status, dtype: int64
#
#
# 3    557
# 2    557
# 1    229
# 4    218
# 0     20
# Name: No_of_Dependents, dtype: int64
#
#
# Yes    792
# No     789
# Name: Personal_loan, dtype: int64
#
#
# No     1054
# Yes     527
# Name: House_loan, dtype: int64
#
#
# Yes    868
# No     713
# Name: Partner_working, dtype: int64
#
#
# Sedan        702
# Hatchback    582
# SUV          297
# Name: Make, dtype: int64

# %%
#Bivariate Analysis

# %%
plt.scatter(df['Age'],df['Price']);

# %%
plt.scatter(df['Partner_salary'],df['Total_salary']);

# %%
fig, axes = plt.subplots(nrows=2,ncols=4)
fig.set_size_inches(12,12)
sns.countplot(x='Education', hue='Gender',data=df, palette='pastel',ax=axes[0][0])
sns.countplot(x='Profession', hue='Gender', data=df, palette='pastel',ax=axes[0][1])
sns.countplot(x='Marital_status', hue='Gender', data=df, palette='pastel',ax=axes[0][2])
sns.countplot(x='No_of_Dependents', hue='Gender', data=df, palette='pastel',ax=axes[0][3])
sns.countplot(x='Personal_loan', hue='Gender', data=df, palette='pastel',ax=axes[1][0])
sns.countplot(x='House_loan', hue='Gender', data=df, palette='pastel',ax=axes[1][1])
sns.countplot(x='Make', hue='Gender', data=df, palette='pastel',ax=axes[1][2])
sns.countplot(x='Make', hue='Profession', data=df, palette='pastel',ax=axes[1][3])
plt.show()

# %%
pd.crosstab(df['Education'], df['Gender'], margins=True)
# Out:
# Gender         Female  Male   All
# Education
# Graduate          138   439   577
# Post Graduate     191   760   951
# All               329  1199  1528

# %%
pd.crosstab(df['Profession'], df['Gender'], margins=True)
# Out:
# Gender      Female  Male   All
# Profession
# Business       105   559   664
# Salaried       224   640   864
# All            329  1199  1528

# %%
pd.crosstab(df['Marital_status'], df['Gender'], margins=True)
# Out:
# Gender          Female  Male   All
# Marital_status
# Married            307  1088  1395
# Single              22   111   133
# All                329  1199  1528

# %%
pd.crosstab(df['No_of_Dependents'], df['Gender'], margins=True)
# Out:
# Gender            Female  Male   All
# No_of_Dependents
# 0                      3    16    19
# 1                     99   126   225
# 2                    135   409   544
# 3                     66   465   531
# 4                     26   183   209
# All                  329  1199  1528

# %%
pd.crosstab(df['Personal_loan'], df['Gender'], margins=True)
# Out:
# Gender         Female  Male   All
# Personal_loan
# No                180   580   760
# Yes               149   619   768
# All               329  1199  1528

# %%
pd.crosstab(df['House_loan'], df['Gender'], margins=True)
# Out:
# Gender      Female  Male   All
# House_loan
# No             244   774  1018
# Yes             85   425   510
# All            329  1199  1528

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt=".2f");

# %%
df[['Gender','Marital_status','Profession','Make']].value_counts()
# Out:
# Gender  Marital_status  Profession  Make
# Male    Married         Salaried    Sedan        266
#                                     Hatchback    245
#                         Business    Hatchback    239
#                                     Sedan        227
# Female  Married         Salaried    SUV          113
#                                     Sedan         84
# Male    Married         Salaried    SUV           79
# Female  Married         Business    SUV           53
# Male    Single          Business    Hatchback     50
# Female  Married         Business    Sedan         43
# Male    Married         Business    SUV           32
#         Single          Salaried    Hatchback     31
# Female  Married         Salaried    Hatchback     14
# Male    Single          Salaried    Sedan         13
#                         Business    Sedan         10
# Female  Single          Salaried    Sedan          7
#                         Business    Sedan          7
# ...

# %%
#key Questions

# %%
sns.countplot(x='Make', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
sns.countplot(x='Make', hue='Marital_status', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
sns.countplot(x='Make', hue='Profession', data=df)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
pd.crosstab(df['Make'], df['Profession'], margins=True,normalize=True)*100
# Out:
# Profession   Business   Salaried         All
# Make
# Hatchback   18.342821  18.469323   36.812144
# SUV          5.629349  13.156230   18.785579
# Sedan       19.354839  25.047438   44.402277
# All         43.327008  56.672992  100.000000

# %%
df[['Profession','Gender','Make']].value_counts(normalize=True)*100
# Out:
# Profession  Gender  Make
# Business    Male    Hatchback    18.913613
# Salaried    Male    Sedan        18.259162
#                     Hatchback    18.062827
# Business    Male    Sedan        15.510471
# Salaried    Female  SUV           7.722513
#                     Sedan         5.955497
#             Male    SUV           5.562827
# Business    Female  SUV           3.599476
#                     Sedan         3.272251
#             Male    SUV           2.159686
# Salaried    Female  Hatchback     0.981675
# dtype: float64

# %%
df.groupby(['Make','Gender'])['Price'].sum()
# Out:
# Make       Gender
# Hatchback  Female      412000
#            Male      14959000
# SUV        Female     9252000
#            Male       7031000
# Sedan      Female     6031000
#            Male      17358000
# Name: Price, dtype: int64

# %%
df.groupby(['Personal_loan'])['Price'].sum()
# Out:
# Personal_loan
# No     28990000
# Yes    27290000
# Name: Price, dtype: int64

# %%
df.groupby(['Personal_loan','Make'])['Price'].sum()
# Out:
# Personal_loan  Make
# No             Hatchback     7765000
#                SUV          10373000
#                Sedan        10852000
# Yes            Hatchback     7643000
#                SUV           6207000
#                Sedan        13440000
# Name: Price, dtype: int64

# %%
df.groupby(['Partner_working','Make'])['Price'].describe()
# Out:
#                            count          mean           std      min  \
# Partner_working Make
# No              Hatchback  281.0  26323.843416   4147.947104  18000.0
#                 SUV        144.0  56173.611111   8873.099017  31000.0
#                 Sedan      288.0  35354.166667  11016.597393  18000.0
# Yes             Hatchback  301.0  26614.617940   4421.649647  19000.0
#                 SUV        153.0  55496.732026   9549.127945  31000.0
#                 Sedan      414.0  34082.125604  11229.200059  18000.0
#
#                                25%      50%      75%      max
# Partner_working Make
# No              Hatchback  23000.0  26000.0  30000.0  33000.0
#                 SUV        51000.0  58000.0  63000.0  70000.0
#                 Sedan      26000.0  34000.0  45000.0  55000.0
# Yes             Hatchback  22000.0  28000.0  30000.0  33000.0
#                 SUV        51000.0  57000.0  62000.0  70000.0
# ...

# %%
df.groupby(['Partner_working','Make'])['Price'].value_counts()
# Out:
# Partner_working  Make       Price
# No               Hatchback  25000    27
#                             30000    27
#                             32000    27
#                             28000    25
#                             20000    23
#                                      ..
# Yes              Sedan      45000     5
#                             51000     5
#                             55000     5
#                             40000     4
#                             22000     1
# Name: Price, Length: 163, dtype: int64

# %%
sns.boxplot(x='Make',y='Price', hue='Partner_working', data=df);

# %%
pd.crosstab(df['Price'], df['Partner_working'], margins=True,normalize=True)*100
# Out:
# Partner_working         No        Yes         All
# Price
# 18000             1.012018   1.328273    2.340291
# 19000             1.075269   1.771031    2.846300
# 20000             2.024035   2.972802    4.996837
# 21000             1.012018   1.454775    2.466793
# 22000             1.518027   1.960784    3.478811
# 23000             2.403542   2.277040    4.680582
# 24000             1.834282   2.213789    4.048071
# 25000             1.707780   1.265022    2.972802
# 26000             1.391524   2.024035    3.415560
# 27000             1.138520   2.087287    3.225806
# 28000             1.897533   2.340291    4.237824
# 29000             1.391524   1.897533    3.289058
# 30000             1.834282   2.024035    3.858318
# 31000             2.340291   2.530044    4.870335
# 32000             2.530044   3.036053    5.566097
# 33000             1.454775   2.024035    3.478811
# 34000             0.632511   0.569260    1.201771
# 35000             0.632511   0.506009    1.138520
# ...

# %%
#problem 2

# %%
df1=pd.read_excel('godigt_cc_data.xlsx')

# %%
df1.head()
# Out:
#    userid              card_no  card_bin_no Issuer   card_type  \
# 0       1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1       2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2       3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3       4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4       5  4377 48XX XXXX XXXX       437748   Visa        edge
#
#   card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0       2019-09-29             B          0          1          1  ...
# 1       2002-10-30             A          1          1          1  ...
# 2       2013-10-05             C          0          0          0  ...
# 3       1999-06-01             E          0          1          1  ...
# 4       2006-06-13             B          1          1          1  ...
#
#    bank_vintage  T+1_month_activity  T+2_month_activity T+3_month_activity  \
# 0            27                   0                   0                  0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userid                   8448 non-null   int64
#  1   card_no                  8448 non-null   object
#  2   card_bin_no              8448 non-null   int64
#  3   Issuer                   8448 non-null   object
#  4   card_type                8448 non-null   object
#  5   card_source_date         8448 non-null   datetime64[ns]
#  6   high_networth            8448 non-null   object
#  7   active_30                8448 non-null   int64
#  8   active_60                8448 non-null   int64
#  9   active_90                8448 non-null   int64
#  10  cc_active30              8448 non-null   int64
#  11  cc_active60              8448 non-null   int64
#  12  cc_active90              8448 non-null   int64
#  13  hotlist_flag             8448 non-null   object
# ...

# %%
print("no. of rows: ",df1.shape[0], "\n""no. of columns: ",df1.shape[1])
# Out:
# no. of rows:  8448
# no. of columns:  28

# %%
df1.isnull().sum()
# Out:
# userid                       0
# card_no                      0
# card_bin_no                  0
# Issuer                       0
# card_type                    0
# card_source_date             0
# high_networth                0
# active_30                    0
# active_60                    0
# active_90                    0
# cc_active30                  0
# cc_active60                  0
# cc_active90                  0
# hotlist_flag                 0
# widget_products              0
# engagement_products          0
# annual_income_at_source      0
# other_bank_cc_holding        0
# bank_vintage                 0
# T+1_month_activity           0
# T+2_month_activity           0
# T+3_month_activity           0
# T+6_month_activity           0
# T+12_month_activity          0
# Transactor_revolver         38
# avg_spends_l3m               0
# Occupation_at_source       261
# cc_limit                     0
# dtype: int64

# %%
df1['card_no'].unique()
# Out:
# array(['4384 39XX XXXX XXXX', '4377 48XX XXXX XXXX',
#        '4258 06XX XXXX XXXX', '5241 78XX XXXX XXXX',
#        '4055 33XX XXXX XXXX', '4375 51XX XXXX XXXX',
#        '4386 28XX XXXX XXXX', '4262 41XX XXXX XXXX', '37694 5XXXX XXXXX',
#        '4477 47XX XXXX XXXX', '37691 6XXXX XXXXX'], dtype=object)

# %%
df1['Issuer'].unique()
# Out:
# array(['Visa', 'Mastercard', 'Amex'], dtype=object)

# %%
df1['card_type'].unique()
# Out:
# array(['edge', 'prosperity', 'rewards', 'indianoil', 'cashback',
#        'shoprite', 'chartered', 'aura', 'gold', 'smartearn', 'prime',
#        'pulse', 'platinum', 'centurion', 'elite'], dtype=object)

# %%
df1['high_networth'].unique()
# Out:
# array(['B', 'A', 'C', 'E', 'D'], dtype=object)

# %%
df1['hotlist_flag'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df1['other_bank_cc_holding'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df1['Transactor_revolver'].unique()
# Out:
# array(['T', 'R', nan], dtype=object)

# %%
df1['Occupation_at_source'].unique()
# Out:
# array(['Self Employed', None, 'Student', 'Salaried', 'Retired',
#        'Housewife'], dtype=object)

# %%
df1['Occupation_at_source'].replace(0, None, inplace=True)

# %%
df1.describe().T
# Out:
#                           count          mean           std       min  \
# userid                   8448.0  4.224500e+03  2.438872e+03       1.0
# card_bin_no              8448.0  4.367470e+05  3.048975e+04  376916.0
# active_30                8448.0  2.923769e-01  4.548815e-01       0.0
# active_60                8448.0  4.947917e-01  5.000025e-01       0.0
# active_90                8448.0  6.420455e-01  4.794271e-01       0.0
# cc_active30              8448.0  2.840909e-01  4.510070e-01       0.0
# cc_active60              8448.0  4.844934e-01  4.997891e-01       0.0
# cc_active90              8448.0  6.323390e-01  4.821970e-01       0.0
# widget_products          8448.0  3.614583e+00  2.273193e+00       0.0
# engagement_products      8448.0  3.991122e+00  2.572135e+00       0.0
# annual_income_at_source  8448.0  1.674595e+06  1.064307e+06  200095.0
# bank_vintage             8448.0  3.316418e+01  1.586834e+01       6.0
# ...

# %%
df1['card_bin_no'].value_counts()
# Out:
# 426241    2084
# 425806    1228
# 437748    1045
# 438628    1005
# 437551     854
# 524178     728
# 438439     489
# 405533     301
# 376945     279
# 447747     273
# 376916     162
# Name: card_bin_no, dtype: int64

# %%
df1['active_30'].value_counts()
# Out:
# 0    5978
# 1    2470
# Name: active_30, dtype: int64

# %%
df1['active_60'].value_counts()
# Out:
# 0    4268
# 1    4180
# Name: active_60, dtype: int64

# %%
df1['active_90'].value_counts()
# Out:
# 1    5424
# 0    3024
# Name: active_90, dtype: int64

# %%
df1['cc_active30'].value_counts()
# Out:
# 0    6048
# 1    2400
# Name: cc_active30, dtype: int64

# %%
df1['cc_active60'].value_counts()
# Out:
# 0    4355
# 1    4093
# Name: cc_active60, dtype: int64

# %%
df1['cc_active90'].value_counts()
# Out:
# 1    5342
# 0    3106
# Name: cc_active90, dtype: int64

# %%
df1['widget_products'].value_counts()
# Out:
# 7    1132
# 4    1117
# 5    1115
# 6    1062
# 3    1060
# 2    1010
# 1     997
# 0     955
# Name: widget_products, dtype: int64

# %%
df1['engagement_products'].value_counts()
# Out:
# 4    1010
# 3     966
# 1     950
# 8     949
# 5     940
# 0     939
# 6     926
# 7     889
# 2     879
# Name: engagement_products, dtype: int64

# %%
df1['T+1_month_activity'].value_counts()
# Out:
# 0    7508
# 1     940
# Name: T+1_month_activity, dtype: int64

# %%
df1['T+2_month_activity'].value_counts()
# Out:
# 0    8043
# 1     405
# Name: T+2_month_activity, dtype: int64

# %%
df1['T+3_month_activity'].value_counts()
# Out:
# 0    7769
# 1     679
# Name: T+3_month_activity, dtype: int64

# %%
df1['T+6_month_activity'].value_counts()
# Out:
# 0    8373
# 1      75
# Name: T+6_month_activity, dtype: int64

# %%
df1['T+12_month_activity'].value_counts()
# Out:
# 0    8368
# 1      80
# Name: T+12_month_activity, dtype: int64

# %%
fig, axes = plt.subplots(nrows=2,ncols=3)
fig.set_size_inches(10,10)
sns.countplot(x='Issuer', data=df1, palette='pastel',ax=axes[0][0])
sns.countplot(x='high_networth', data=df1, palette='pastel',ax=axes[0][1])
sns.countplot(x='hotlist_flag', data=df1, palette='pastel',ax=axes[0][2])
sns.countplot(x='widget_products', data=df1, palette='pastel',ax=axes[1][0])
sns.countplot(x='engagement_products', data=df1, palette='pastel',ax=axes[1][1])
sns.countplot(x='other_bank_cc_holding', data=df1, palette='pastel',ax=axes[1][2])
plt.show()

# %%
fig, axes = plt.subplots(nrows=4,ncols=3)
fig.set_size_inches(15,15)
sns.countplot(x='active_30', data=df1, palette='pastel',ax=axes[0][0])
sns.countplot(x='active_60', data=df1, palette='pastel',ax=axes[0][1])
sns.countplot(x='active_90', data=df1, palette='pastel',ax=axes[0][2])
sns.countplot(x='T+1_month_activity', data=df1, palette='pastel',ax=axes[1][0])
sns.countplot(x='T+2_month_activity', data=df1, palette='pastel',ax=axes[1][1])
sns.countplot(x='T+3_month_activity', data=df1, palette='pastel',ax=axes[1][2])
sns.countplot(x='T+6_month_activity', data=df1, palette='pastel',ax=axes[2][0])
sns.countplot(x='T+12_month_activity', data=df1, palette='pastel',ax=axes[2][1])
sns.countplot(x='other_bank_cc_holding', data=df1, palette='pastel',ax=axes[2][2])
sns.countplot(x='Transactor_revolver', data=df1, palette='pastel',ax=axes[3][0])
plt.xticks(rotation=90)
sns.countplot(x='Occupation_at_source', data=df1, palette='pastel',ax=axes[3][1])
plt.xticks(rotation=90)
sns.countplot(x='card_type', data=df1, palette='pastel',ax=axes[3][2])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr(),annot=True,fmt=".2f");

# %%
plt.scatter(df1['annual_income_at_source'],df1['cc_limit']);

# %%
plt.scatter(df1['annual_income_at_source'],df1['avg_spends_l3m']);

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='card_type', data=df1, palette='pastel')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='card_type',hue='Occupation_at_source', data=df1, palette='pastel')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Issuer',hue='Occupation_at_source', data=df1, palette='pastel')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='card_type',hue='Issuer', data=df1, palette='pastel')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='high_networth',hue='Occupation_at_source', data=df1, palette='pastel')
plt.show()

# %%
df1[['Issuer','active_30','card_type']].value_counts()
# Out:
# Issuer      active_30  card_type
# Visa        0          rewards       863
#                        prosperity    702
#                        edge          690
#                        chartered     673
#                        smartearn     470
#                        shoprite      454
#                        indianoil     444
#             1          rewards       429
#             0          aura          420
#                        cashback      419
#             1          prosperity    305
#                        edge          290
#                        chartered     250
#                        cashback      194
#                        aura          174
#                        shoprite      174
#                        indianoil     171
#                        smartearn     156
# Amex        0          gold          105
# Mastercard  0          rewards        87
#                        prime          79
#                        pulse          78
# ...

# %%
df1[['Issuer','cc_active30','card_type']].value_counts()
# Out:
# Issuer      cc_active30  card_type
# Visa        0            rewards       926
#                          prosperity    732
#                          edge          679
#                          chartered     647
#                          shoprite      465
#                          smartearn     450
#                          cashback      441
#                          indianoil     431
#                          aura          428
#             1            rewards       366
#                          edge          301
#                          chartered     276
#                          prosperity    275
#                          indianoil     184
#                          smartearn     176
#                          cashback      172
#                          aura          166
#                          shoprite      163
# Amex        0            gold          115
# Mastercard  0            rewards        94
#                          prime          75
# ...

# %%
sns.histplot(data=df1,x='avg_spends_l3m')
# Out:
# <AxesSubplot:xlabel='avg_spends_l3m', ylabel='Count'>

# %%
df1['avg_spends_l3m'].mean()
# Out:
# 49527.36553030303

# %%
sns.histplot(data=df1,x='cc_limit')
# Out:
# <AxesSubplot:xlabel='cc_limit', ylabel='Count'>
